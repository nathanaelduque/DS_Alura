# %% [markdown]
# # Aula 01
#
# ## Fazendo as primeiras visualizações

# %%
import pandas as pd

# %%
df=pd.read_csv('monitoramento_tempo.csv')

# %%
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %% [markdown]
# Vamos verificar se há algum dados faltando utilizando df.info():

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %% [markdown]
# Todos os dados contam com 45253 registros não nulos, a única alteração que queremos fazer é transformar a variável data numa variável do tipo datetime!

# %%
#Convertendo em datetime
df.data = pd.to_datetime(df.data)

# %% [markdown]
# Vamos checar para ver se é mesmo um datetime:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.figure(figsize=(15,8))
plt.plot(df.data,df.temperatura)
plt.title('Temperatura no tempo',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Temperatura no tempo')

# %% [markdown]
# Como a temperatura varia de 260 a 310 provavelmente estamos trabalhando com a escala Kelvin!
#
# Agora vamos criar o gráfico de outra maneira:

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])

# %% [markdown]
# Primeiramente criamos o gráfico em si, agora vamos colocar a Figura dentro dele!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura)

eixo.set_title('Temperatura no momento',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Temperatura no momento')

# %% [markdown]
# Dessa maneira conseguimos fazer costumizações mas avançadas na Figura!
#
# Vamos colocar legendas no eixos!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura)

eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Vamos colocar mais uma legenda no gráfico:

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura)

eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)

# %% [markdown]
# Vamos agora trocar a cor desse gráfico:

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura,color='green')

eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)

# %% [markdown]
# # Aula 02
#
# ## Customizando nossas visualizações

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura,color='g',lw=4) #g: abreviação para green ;  lw: line width

eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)

# %% [markdown]
# A espessura da linha deixou o gráfico pior! Vamos então tentar deixar a linha mais fina:

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura,color='g',lw=0.4) #g: abreviação para green ;  lw: line width

eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)

# %% [markdown]
# Também não ficou muito bom, a espessura mais fina!Vamos deixar no padrão, que é 1.

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura,color='g',ls='dotted') #g: abreviação para green ;  lw: line width; ls:line style

eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)

# %% [markdown]
# O Linestyle(ls) também não ajudou muito na visualização!
#
# Vamos tentar mostrar o gráfico somente de 2014 até 2015!

# %%
import datetime

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura,color='g') #g: abreviação para green ;  lw: line width; ls:line style

eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))  #(2014,1,1)--> 01/01/2014
eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)

# %% [markdown]
# Começo e final do ano são meses mais frios, enquanto que no meio do ano faz mais calor!
#
# A partir disso, podemos dizer que estamos lidando com dados do hemisfério norte!
#
# Agora vamos adicionar marcadores na nossa visualização!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura,color='g',marker='o') #g: abreviação para green ;  lw: line width; ls:line style

eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))  #(2014,1,1)--> 01/01/2014
eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)

# %% [markdown]
# Nossa visualização ficou pior com esses marcadores, vamos retirá-los então!
#
# Vamos adicionar uma grade no nosso gráfico!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df.data,df.temperatura,color='g') #g: abreviação para green ;  lw: line width; ls:line style

eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))  #(2014,1,1)--> 01/01/2014
eixo.set_title('Temperatura no momento',fontsize=25)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)
eixo.grid(True)

# %% [markdown]
# Agora vamos fazer uma visualização dentro de uma visualização dentro da mesma figura!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo2=fig.add_axes([0.1,0.5,0.4,0.4])

# %% [markdown]
# Agora vamos adicionar as Figuras nessas séries!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo2=fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df.data,df.temperatura,color='g')
eixo.set_title('Temperatura no momento',fontsize=25,pad=20) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo.legend(['temperatura'],loc='best',fontsize=15)

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo2=fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df.data,df.temperatura,color='g')
eixo.set_title('Temperatura no momento',fontsize=25,pad=20) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo.legend(['temperatura'],loc='best',fontsize=15)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)

eixo.grid(True)
eixo2.plot(df.data,df.temperatura,color='b')
eixo2.set_title('Temperatura no momento',fontsize=15) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo2.legend(['temperatura'],loc='best',fontsize=8)
eixo2.set_ylabel('Temperatura',fontsize=10)
eixo2.set_xlabel('Data',fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Vamos trocar a posição do segundo eixo!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo2=fig.add_axes([0.7,0.65,0.3,0.3]) # Aqui conseguimos trocar a posição do eixo 2

eixo.grid(True)
eixo.plot(df.data,df.temperatura,color='g')
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))  #(2014,1,1)--> 01/01/2014
eixo.set_title('Temperatura em 2014',fontsize=25,pad=20) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo.legend(['temperatura'],loc='lower right',fontsize=15)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)

eixo2.grid(True)
eixo2.plot(df.data,df.temperatura,color='b')
eixo2.set_title('Temperatura no momento',fontsize=15) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo2.legend(['temperatura'],loc='best',fontsize=8)
eixo2.set_ylabel('Temperatura',fontsize=10)
eixo2.set_xlabel('Data',fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Agora vamos ver como se comportou a temperatura no mês de maio de 2014 no gráfico maior , enquanto que no gráfico menor vemos o comportamento da temperatura no ano de 2014.

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo2=fig.add_axes([0.7,0.65,0.3,0.3]) # Aqui conseguimos trocar a posição do eixo 2

eixo.grid(True)
eixo.plot(df.data,df.temperatura,color='g')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))  #(2014,1,1)--> 01/01/2014
eixo.set_title('Temperatura em 2014',fontsize=25,pad=20) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo.legend(['temperatura'],loc='lower right',fontsize=15)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)

eixo2.grid(True)
eixo2.plot(df.data,df.temperatura,color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))  #(2014,1,1)--> 01/01/2014
eixo2.set_title('Temperatura no momento',fontsize=15) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo2.legend(['temperatura'],loc='best',fontsize=8)
eixo2.set_ylabel('Temperatura',fontsize=10)
eixo2.set_xlabel('Data',fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Vamos trocar os limites do mês de maio!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo2=fig.add_axes([0.7,0.65,0.3,0.3]) # Aqui conseguimos trocar a posição do eixo 2

eixo.grid(True)
eixo.plot(df.data,df.temperatura,color='g')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))  #(2014,1,1)--> 01/01/2014
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em Maio de 2014',fontsize=25,pad=20) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo.legend(['temperatura'],loc='lower right',fontsize=15)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)

eixo2.grid(True)
eixo2.plot(df.data,df.temperatura,color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))  #(2014,1,1)--> 01/01/2014
eixo2.set_title('Temperatura em 2014',fontsize=15) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo2.legend(['temperatura'],loc='best',fontsize=8)
eixo2.set_ylabel('Temperatura',fontsize=10)
eixo2.set_xlabel('Data',fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Vamos destacar o mês de maio no gráfico melhor!

# %%
fig=plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])
eixo2=fig.add_axes([0.7,0.65,0.3,0.3]) # Aqui conseguimos trocar a posição do eixo 2

eixo.grid(True)
eixo.plot(df.data,df.temperatura,color='g')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))  #(2014,1,1)--> 01/01/2014
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em Maio de 2014',fontsize=25,pad=20) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo.legend(['temperatura'],loc='lower right',fontsize=15)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.set_xlabel('Data',fontsize=20)

eixo2.grid(True)
eixo2.plot(df.data,df.temperatura,color='g')
#Filtro para mudar a cor:
azul_esquerda=df.data < datetime.datetime(2014,5,1)
azul_direita=df.data > datetime.datetime(2014,6,1)
eixo2.plot(df[azul_esquerda]['data'],df[azul_esquerda]['temperatura'],color='b')
eixo2.plot(df[azul_direita]['data'],df[azul_direita]['temperatura'],color='b')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))  #(2014,1,1)--> 01/01/2014
eixo2.set_title('Temperatura em 2014',fontsize=15) #pad = 20 dar uma espaçada entre o eixo e a Figura 
eixo2.legend(['temperatura'],loc='best',fontsize=8)
eixo2.set_ylabel('Temperatura',fontsize=10)
eixo2.set_xlabel('Data',fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# # Aula 3

# %%
fig = plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])

eixo.plot(df.data,df.temperatura, color='g')
eixo.set_title('Temperatura no momento',fontsize=25,pad=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)
eixo.grid(True)

eixo.axhline(max(df.temperatura),color='k',linestyle='--')# k:Preto
eixo.axhline(min(df.temperatura),color='k',linestyle='--')

# %% [markdown]
# Vamos colocar também uma notação!

# %%
fig = plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])

eixo.plot(df.data,df.temperatura, color='g')
eixo.set_title('Temperatura no momento',fontsize=25,pad=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)
eixo.grid(True)

x1=df['data'][df['temperatura'].idxmax()]
y1=max(df.temperatura)

#Adicionando a Notação!
eixo.annotate('Máximo',xy=(x1,y1),fontsize=20)

eixo.axhline(max(df.temperatura),color='k',linestyle='--')# k:Preto
eixo.axhline(min(df.temperatura),color='k',linestyle='--')

# %% [markdown]
# Ficou muito próximo da linha, vamos então colocar uma seta, para indicar o máximo!

# %%
fig = plt.figure(figsize=(15,8))
eixo=fig.add_axes([0,0,1,1])

eixo.plot(df.data,df.temperatura, color='g')
eixo.set_title('Temperatura no momento',fontsize=25,pad=20)
eixo.set_xlabel('Data',fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.legend(['Temperatura'],loc='lower right',fontsize=15)
eixo.grid(True)


# Para colocar a notação do máximo + seta:
x1=df['data'][df['temperatura'].idxmax()]
y1=max(df.temperatura)

x2=df['data'][df['temperatura'].idxmax()-7000]
y2=max(df.temperatura) - 5

#Adicionando a Notação!
eixo.annotate('Máximo',xy=(x1,y1),fontsize=20,xytext=(x2,y2),arrowprops = dict(facecolor = 'k'))

# Para colocar a notação do mínimo + seta:
x1=df['data'][df['temperatura'].idxmin()]
y1=min(df.temperatura)

x2=df['data'][df['temperatura'].idxmin()-7000]
y2=min(df.temperatura) + 5

#Adicionando a Notação!
eixo.annotate('Mínimo',xy=(x1,y1),fontsize=20,xytext=(x2,y2),arrowprops = dict(facecolor = 'k'))


#Adicionando a Linha Tracejada
eixo.axhline(max(df.temperatura),color='k',linestyle='--')# k:Preto
eixo.axhline(min(df.temperatura),color='k',linestyle='--')

# %% [markdown]
# Verificando o dia da semana mais quente:

# %%
temperatura_por_dia_da_semana= df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias=['Domingo','Segunda','Terça','Quarta','Quinta','Sexta','Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %% [markdown]
# São muito próximos uma das outras!

# %%
#Eu fiz dessa maneira para se ter os dias da semana no eixo x
fig=plt.figure(figsize=(5,4))
eixo=fig.add_axes([0,0,1,1])

indice=nome_dias#range(len(temperatura_por_dia_da_semana))
eixo.bar(indice,temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia  da semana',fontsize=15,pad=10)
eixo.set_xlabel('Dia da Semana',fontsize=15)
eixo.set_ylabel('Temperatura Média',fontsize=15)
# Out:
# Text(0, 0.5, 'Temperatura Média')

# %%
#O prof fez dessa maneira:
fig=plt.figure(figsize=(5,4))
eixo=fig.add_axes([0,0,1,1])

indice=nome_dias#range(len(temperatura_por_dia_da_semana))
eixo.bar(indice,temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia  da semana',fontsize=15,pad=10)
eixo.set_xlabel('Dia da Semana',fontsize=15)
eixo.set_ylabel('Temperatura Média',fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0.0, 0, 'Domingo'),
#  Text(1.0, 0, 'Segunda'),
#  Text(2.0, 0, 'Terça'),
#  Text(3.0, 0, 'Quarta'),
#  Text(4.0, 0, 'Quinta'),
#  Text(5.0, 0, 'Sexta'),
#  Text(6.0, 0, 'Sábado')]

# %%
fig=plt.figure(figsize=(5,4))
eixo=fig.add_axes([0,0,1,1])

indice=nome_dias#range(len(temperatura_por_dia_da_semana))
cores=['black','r','g','b','yellow','orange','magenta']

eixo.bar(indice,temperatura_por_dia_da_semana, color=cores)
eixo.set_title('Temperatura por dia  da semana',fontsize=15,pad=10)
eixo.set_xlabel('Dia da Semana',fontsize=15)
eixo.set_ylabel('Temperatura Média',fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0.0, 0, 'Domingo'),
#  Text(1.0, 0, 'Segunda'),
#  Text(2.0, 0, 'Terça'),
#  Text(3.0, 0, 'Quarta'),
#  Text(4.0, 0, 'Quinta'),
#  Text(5.0, 0, 'Sexta'),
#  Text(6.0, 0, 'Sábado')]

# %% [markdown]
# Creio que um gráfico  tão colorido assim não seja tão  agradável

# %%
fig=plt.figure(figsize=(5,4))
eixo=fig.add_axes([0,0,1,1])

indice=nome_dias#range(len(temperatura_por_dia_da_semana))
cores=['black','r','g','b','yellow','orange','magenta']

eixo.bar(indice,temperatura_por_dia_da_semana, color=cores,edgecolor='black')
eixo.set_title('Temperatura por dia  da semana',fontsize=15,pad=10)
eixo.set_xlabel('Dia da Semana',fontsize=15)
eixo.set_ylabel('Temperatura Média',fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0.0, 0, 'Domingo'),
#  Text(1.0, 0, 'Segunda'),
#  Text(2.0, 0, 'Terça'),
#  Text(3.0, 0, 'Quarta'),
#  Text(4.0, 0, 'Quinta'),
#  Text(5.0, 0, 'Sexta'),
#  Text(6.0, 0, 'Sábado')]

# %% [markdown]
# Agora vamo lidar com os gráficos de pizza

# %%
fig=plt.figure(figsize=(5,4))
eixo=fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana,labels = temperatura_por_dia_da_semana.index, 
        autopct='%0.1f%%')
eixo.set_title('Temperatura por dia da semana',fontsize=15,pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %% [markdown]
# É praticamente a  mesma temperatura média para todos os dias da semana!

# %%
fig=plt.figure(figsize=(5,4))
eixo=fig.add_axes([0,0,1,1])

# Vamos dar destaque a alguns dias da semana:
explodir=[0.1,0,0,0,0,0.1,0.1]

eixo.pie(temperatura_por_dia_da_semana,labels = temperatura_por_dia_da_semana.index, 
        autopct='%0.1f%%',explode=explodir,shadow=True)
eixo.set_title('Temperatura por dia da semana',fontsize=15,pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')
